# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# **1.** What is the distribution of body mass in the penguins dataset?

# %%
# Write your code here

# %% [markdown]
# **2.** Is there a relationship between flipper length and body mass?

# %%
# Write your code here

# %% [markdown]
# **3.** How does species affect flipper length?

# %%
# Write your code here

# %% [markdown]
# **4.** What are the average body mass values by sex?

# %%
# Write your code here

# %% [markdown]
# **5.** How does island location impact body mass?

# %%
# Write your code here

# %% [markdown]
# **6.** What is the distribution of bill length based on sex?

# %%
# Write your code here

# %% [markdown]
# **7.** What is the mean flipper length for each species?

# %%
# Write your code here

# %% [markdown]
# **8.** How does bill length vary with body mass?

# %%
# Write your code here

# %% [markdown]
# **9.** How does body mass change across islands?

# %%
# Write your code here

# %% [markdown]
# **10.** What is the relationship between flipper length, bill depth, and species?

# %%
# Write your code here

# %% [markdown]
# **11.** How is bill depth distributed based on island and species?

# %%
# Write your code here

# %% [markdown]
# **12.** What is the trend between bill length and bill depth across species?

# %%
# Write your code here
