# %%
#importing a file from CSv file
import pandas as pd

# %%
# Read csv file into a pandas dataframe.pleasea change location as per your computer
df = pd.read_csv("supermarket.csv", header = 0)

# %%
# Display first few rows of the dataset
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Read xlsx file into a pandas dataframe
df1 = pd.read_excel("Olympic Athletes.xlsx", header = 0)
# Display first few rows of the dataset
df1.head()
# Out:
#             Unnamed: 0     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                  NaN            NaN         NaN         NaN         NaN
# 1  Sum of Total Medals  Column Labels         NaN         NaN         NaN
# 2           Row Labels           2000      2002.0      2004.0      2006.0
# 3          Afghanistan            NaN         NaN         NaN         NaN
# 4              Algeria            NaN         NaN         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2      2008.0      2010.0      2012.0  Grand Total
# 3         1.0         NaN         1.0            2
# 4         2.0         NaN         NaN            2

# %%
#read a text file
df2 = pd.read_table("iris.txt")
# Display first few rows of the dataset
df2.head()
# Out:
#   sepal length,sepal width,petal length,petal width,Iris plant
# 0                        5.1,3.5,1.4,0.2,Iris-setosa
# 1                        4.9,3.0,1.4,0.2,Iris-setosa
# 2                        4.7,3.2,1.3,0.2,Iris-setosa
# 3                        4.6,3.1,1.5,0.2,Iris-setosa
# 4                        5.0,3.6,1.4,0.2,Iris-setosa

# %%
#to split using a seperator
df2 = pd.read_table("iris.txt" , sep=',')
# Display first few rows of the dataset
df2.head()
# Out:
#    sepal length  sepal width  petal length  petal width   Iris plant
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#different options in import
df3 = pd.read_csv("supermarket.csv", header = None)
# Load data from CSV file
df4 = pd.read_csv("supermarket.csv", header = 0)
# Load data from CSV file
df5 = pd.read_csv("supermarket.csv", header = 1)

# %%
# Display first few rows of the dataset
df3.head()
# Out:
#             0       1          2              3       4   \
# 0   Invoice ID  Branch       City  Customer type  Gender
# 1  750-67-8428       A     Yangon         Member  Female
# 2  226-31-3081       C  Naypyitaw         Normal  Female
# 3  631-41-3108       A     Yangon         Normal    Male
# 4  123-19-1176       A     Yangon         Member    Male
#
#                        5           6         7        8         9          10  \
# 0            Product line  Unit price  Quantity   Tax 5%     Total       Date
# 1       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 2  Electronic accessories       15.28         5     3.82     80.22   3/8/2019
# 3      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 4       Health and beauty       58.22         8   23.288   489.048  1/27/2019
#
#       11           12      13                       14            15      16
# ...

# %%
# Display first few rows of the dataset
df4.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# Display first few rows of the dataset
df5.head()
# Out:
#    750-67-8428  A     Yangon  Member  Female       Health and beauty  74.69  \
# 0  226-31-3081  C  Naypyitaw  Normal  Female  Electronic accessories  15.28
# 1  631-41-3108  A     Yangon  Normal    Male      Home and lifestyle  46.33
# 2  123-19-1176  A     Yangon  Member    Male       Health and beauty  58.22
# 3  373-73-7910  A     Yangon  Normal    Male       Sports and travel  86.31
# 4  699-14-3026  C  Naypyitaw  Normal    Male  Electronic accessories  85.39
#
#    7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83  4.761904762  \
# 0  5   3.8200   80.2200   3/8/2019  10:29         Cash   76.40     4.761905
# 1  7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31     4.761905
# 2  8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76     4.761905
# 3  7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17     4.761905
# 4  7  29.8865  627.6165  3/25/2019  18:30      Ewallet  597.73     4.761905
#
#    26.1415.1  9.1
# 0     3.8200  9.6
# ...

# %%
# Load data from CSV file
df6 = pd.read_csv("supermarket.csv", header = None)
df6=df6.add_prefix("var")

# %%
# Display first few rows of the dataset
df6.head()
# Out:
#           var0    var1       var2           var3    var4  \
# 0   Invoice ID  Branch       City  Customer type  Gender
# 1  750-67-8428       A     Yangon         Member  Female
# 2  226-31-3081       C  Naypyitaw         Normal  Female
# 3  631-41-3108       A     Yangon         Normal    Male
# 4  123-19-1176       A     Yangon         Member    Male
#
#                      var5        var6      var7     var8      var9      var10  \
# 0            Product line  Unit price  Quantity   Tax 5%     Total       Date
# 1       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 2  Electronic accessories       15.28         5     3.82     80.22   3/8/2019
# 3      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 4       Health and beauty       58.22         8   23.288   489.048  1/27/2019
#
#    var11        var12   var13                    var14         var15   var16
# ...

# %%
# you can skip any rows if you want
df = pd.read_csv("supermarket.csv", header = 0, skiprows=[1,2])

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    631-41-3108      A     Yangon        Normal    Male
# 1    123-19-1176      A     Yangon        Member    Male
# 2    373-73-7910      A     Yangon        Normal    Male
# 3    699-14-3026      C  Naypyitaw        Normal    Male
# 4    355-53-5943      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 993  233-67-5758      C  Naypyitaw        Normal    Male
# 994  303-96-2227      B   Mandalay        Normal  Female
# 995  727-02-1313      A     Yangon        Member    Male
# 996  347-56-2442      A     Yangon        Normal    Male
# 997  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0        Home and lifestyle       46.33         7  16.2155   340.5255
# 1         Health and beauty       58.22         8  23.2880   489.0480
# ...

# %%
#export back to csv file witha new name export
df.to_csv (r'export.csv', index = False, header=True)

# %%
#export back to csv file witha new name export
df.to_excel (r'export1.xlsx', index = False, header=True)
